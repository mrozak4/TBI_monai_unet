# %%
import numpy as np
from skimage import io
import networkx as nx
import re
from pathlib import Path
import os
import scipy as sp
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar
from skimage import exposure
from tqdm import tqdm
import scipy as sp

# %%
folder = Path('matt_preds_graphs_fwhm_single_excel/')
files  = list(folder.glob('*amended_full*.pickle'))
files  = sorted([x.as_posix() for x in files])
files = [x for x in files if '_0001' in x]
files = [x for x in files if '06162021_4' not in x]
files = [x for x in files if '20200217_14' not in x]
files = [x for x in files if '20200217_7' not in x]
files = [x for x in files if '06162021_4' not in x]
files = [x for x in files if 'forepaw' not in x]
len(files)
# Out:
# 277

# %%
graph.edges[edge].keys()
graph.edges[edge]['weight']
# Out:
# 184.31132869559443

# %%
res = []
for j, file_0001 in enumerate(files[:]):
    file = re.sub('_0001','',file_0001)
    graph = nx.read_gpickle(file)
    graph_0001 = nx.read_gpickle(file_0001)
    if len(list(graph_0001)) == len(list(graph)):
        for i,edge in enumerate(graph.edges):
            radii = graph.edges[edge]['radii']
            radii_0001 = graph_0001.edges[edge]['radii']
            if 0.9>abs(radii_0001-radii)/radii>0.5 and 4 > radii > 2 and (graph.edges[edge]['start_depth'] == 0 or graph.edges[edge]['start_depth'] == 250.8) and graph.edges[edge]['weight'] > 70:
                if 150>len(graph.edges[edge]['pts'])>40: # and 50 < graph.edges[edge]['mean_depth'] < 200:
                    #print(file)
                    print(j, i, radii_0001-radii, radii)
                    res.append(tuple((j,i)))
# Out:
# 13 2 -1.440320094979195 2.6365805066228982
# 14 33 -2.049172861498243 3.0608580008521273
# 17 317 1.3813196489779411 2.2510362083775854
# 20 207 -1.8665853294162942 3.540312358681926
# 35 307 -1.074550447812995 2.0053488288294807
# 45 595 -1.274644925593842 2.4648732252496957
# 49 134 -1.242988560716265 2.1685600667882454
# 57 340 -1.2735664727303313 2.5079186337613195
# 57 602 -1.2083619347107135 2.2956964788406453
# 58 66 -1.242962208577413 2.15395354464244
# 58 247 -1.4488507539703464 2.4162076114673368
# 58 300 -1.3794714250047722 2.6110990397724034
# 58 363 -1.2125078263676268 2.414480558978734
# 58 401 -1.0418518166058297 2.052511714709397
# 58 438 -1.3404751067595655 2.231699263747789
# 58 441 -1.1410754559787444 2.0670648986480926
# 58 503 -1.0790370717636457 2.068185298285709
# 58 525 -1.399140428590885 2.5526864908329863
# 68 327 1.4596257815902138 2.6801427417522046
# 81 34 -2.0852069812416714 2.814765805830484
# 81 207 -1.5035840151901674 2.673236746298428
# 85 21 1.2410359650365668 2.2768172625493355
# 91 315 1.6426361423423312 2.6721126825604298
# 92 24 1.9207340542278937 3.0354257911870395
# 95 0 -1.22552085639078 2.429682103952692
# 95 54 -1.4851435151564414 2.464530470589412
# 99 79 -1.3220563780619343 2.356218688425457
# 104 150 -1.103946336498315 2.0716658878677645
# 104 188 -1.835032882809731 2.678427406571563
# 107 55 -1.3316476032674678 2.3492770029814
# 110 53 1.4668986332722125 2.0684381302791928
# 115 92 1.1241729673520817 2.1484502602807134
# 123 22 -1.509650281118391 2.3121909776090073
# 123 54 -1.8511589980250305 2.6642829706338724
# 123 56 -1.9143991496859378 2.8568382877193557
# 123 81 -1.7066359841813412 2.548916858677808
# 123 99 -1.1481845974003995 2.0172113893040295
# 136 120 2.0714369669399626 3.0680427687946614
# 137 58 -1.2739079784989031 2.4438036093790707
# 137 83 -1.6950515330184397 2.888322052305771
# 150 414 2.3278732052223003 2.6183076633863203
# 152 230 -1.1459882993293802 2.2073070879247263
# 161 638 1.2407498131291916 2.0471406889677146
# 163 107 -2.4283623380112926 3.6482561207753457
# 168 10 1.364823864918986 2.3801722028816164
# 176 561 -1.2019502146263614 2.244373119239494
# 177 470 2.9420908576470177 3.4827225103505404
# 184 0 1.210576977698694 2.265785757254362
# 184 90 1.2861220289182267 2.261506994809469
# 184 155 1.936077871967702 3.2743225399583653
# 184 177 2.385247812154157 2.902445206616772
# 184 193 1.8436294018624815 3.0651094872372764
# 185 130 2.2726318785482835 3.555463167116229
# 185 177 1.6988015054962418 3.341726966721703
# 185 193 1.8084482313472696 3.3005837867242045
# 185 250 -1.1910405801652661 2.0631800430801976
# 188 129 1.7691453635206855 3.371074126073159
# 194 113 1.226160133570378 2.0816414920745907
# 194 218 -1.9615848039923247 3.1486959060269983
# 195 113 -1.866894321183509 2.852789876991499
# 195 228 -1.3189651987225057 2.344585661399868
# 195 248 1.3995706725854467 2.0606531839706927
# 195 839 1.5003640856032954 2.037181158631586
# 195 860 1.6107868437140036 3.0325263487257645
# 199 1 -1.3135761973185396 2.2205169426133167
# 199 75 -1.9955901967837988 3.157391470151694
# 199 107 -1.1880067596398514 2.1961255604271517
# 199 110 -1.3715804182924518 2.6623614955449715
# 199 417 -1.9019335328382136 2.8965965777436757
# 199 421 -1.6651624892940822 2.609518377251736
# 201 344 1.2345758468739807 2.252955759982163
# 205 344 1.1507024905246328 2.2050718603845407
# 210 4 -1.450811529084808 2.637536581640766
# 210 105 -1.364802656142789 2.24776359226549
# 210 109 -1.1685924302950457 2.1137911613026
# 210 153 -2.4959847547751606 3.474761853273966
# 210 219 -1.217953804858947 2.396379114189261
# 210 283 1.916483266771699 2.393320696674255
# 210 511 -1.2433738087842303 2.0588276179163665
# 211 393 1.372930351118204 2.6092176881470626
# 213 135 -1.053502943159322 2.0562230358157487
# 213 263 -2.1404899252106864 3.2654607619538636
# 213 475 -1.2588550374528615 2.225500920243906
# 214 70 -2.2163716364425685 3.660343014471131
# 215 76 -1.1575587142009247 2.2156741370521402
# 215 477 -1.2129082401733315 2.1618145472247656
# 216 521 1.1391101652680304 2.0517127780643056
# 221 70 -1.5951143181090228 2.7417691558077157
# 221 275 -1.892253874677473 3.109756776041851

# %%
#res[75:]

# %%
#[17,389],[5,199],[37,507],[24,26],[13,9],[0,18]
#[5,368],[37,307],[24,418],[13,456],[13,394],[17,86]
#files_edge = np.array([[17,389],[37,507],[24,26],[13,9],[0,18]])
#files_edge = np.array([[205,343],[41,367],[49,7],[176,54],[180,291],[199,89]])
files_edge = np.array([[25,271],[57,16],[85,7],[104,329],[150,63],[177,56]])

position = ['lower center','center left', 'lower center','lower left','upper right', 'upper left']
#position = ['lower center','lower center', 'lower center','lower center','lower left', 'upper right']
for params in res[:]:
    print(params)
    fig, ax = plt.subplots(1,2)
    file_0001 = files[params[0]]
    file = re.sub('_0001','',file_0001)
    print(file)
    img = io.imread(re.sub('_radii_amended_full.pickle','.tif',re.sub('matt_preds_graphs_fwhm_single_excel','matt_raw_warped_single',file)))
    img_0001 = io.imread(re.sub('_radii_amended_full.pickle','.tif',re.sub('matt_preds_graphs_fwhm_single_excel','matt_raw_warped_single',file_0001)))
    img_ch2 = sp.ndimage.zoom(np.swapaxes(img[:,1,:,:],0,2),(1,1,2.645833333),order=0)
    img = sp.ndimage.zoom(np.swapaxes(img[:,0,:,:],0,2),(1,1,2.645833333),order=0)
    img_0001_ch2 = sp.ndimage.zoom(np.swapaxes(img_0001[:,1,:,:],0,2),(1,1,2.645833333),order=0)
    img_0001 = sp.ndimage.zoom(np.swapaxes(img_0001[:,0,:,:],0,2),(1,1,2.645833333),order=0)
    graph = nx.read_gpickle(file)
    graph_0001 = nx.read_gpickle(file_0001)
    edges = list(graph.edges)
    edge = edges[params[1]]
    #print(edges[params[1]])
    radii = graph.edges[edge]['radii']
    radii_0001 = graph_0001.edges[edge]['radii']
    pts = graph.edges[edge]['pts']
    mx = np.max(pts,axis=0) +5
    mn = np.min(pts,axis=0) - 5
    mn[mn<0] = 0
    mx[mx>511] = 511
    pt = pts[:,:2]- np.array([mn[0],mn[1]]) - 1
    _img = exposure.equalize_adapthist(np.max(img[mn[0]:mx[0],mn[1]:mx[1],mn[2]:mx[2]],axis=2), clip_limit=0.03)
    _show_img = np.zeros(list(_img.shape) + [3])
    _show_img[:,:,0] = _img
    _show_img[:,:,1] = 0.7*exposure.equalize_adapthist(np.max(img_ch2[mn[0]:mx[0],mn[1]:mx[1],mn[2]:mx[2]],axis=2), clip_limit=0.03)
    ax[0].imshow(_show_img)
    ax[0].tick_params(left = False, right = False, labelleft = False ,labelbottom = False, bottom = False)
    print(radii_0001-radii)
    ax[0].set_ylabel("{:.2f}".format(round((radii_0001-radii)*2, 2)) + str(u' \u03bcm'), rotation=0, fontsize=20, ha='right')
    scalebar = ScaleBar(1,units="um", 
                        length_fraction = 0.5, 
                        location = position[0], 
                        pad=0.1, 
                        color='white', 
                        frameon=False,
                        width_fraction = 0.05) # 1 pixel = 0.2 meter
    scalebar2 = ScaleBar(1,units="um", 
                        length_fraction = 0.5, 
                        location = position[0], 
                        pad=0.1, 
                        color='white', 
                        frameon=False,
                        width_fraction = 0.05) # 1 pixel = 0.2 meter
    ax[0].add_artist(scalebar)
    #ax[i,1].add_artist(scalebar2)
    _img_0001 = np.max(img_0001[mn[0]:mx[0],mn[1]:mx[1],mn[2]:mx[2]],axis=2)
    _show_img_0001 = np.zeros(list(_img_0001.shape) + [3])
    _show_img_0001[:,:,0] = exposure.equalize_adapthist(_img_0001, clip_limit=0.03)
    _show_img_0001[:,:,1] = 0.7*exposure.equalize_adapthist(np.max(img_0001_ch2[mn[0]:mx[0],mn[1]:mx[1],mn[2]:mx[2]],axis=2), clip_limit=0.03)
    ax[1].imshow(_show_img_0001)
    ax[1].tick_params(left = False, right = False , labelleft = False ,labelbottom = False, bottom = False)
    fig.set_figheight(3.5)
    fig.set_figwidth(7)
    fig.tight_layout()
    fig.show()
    plt.pause(1)
#fig.savefig('seeingIsBeiliving_James.png')
# Out:
# (13, 2)
# matt_preds_graphs_fwhm_single_excel/20200217_17-XYZres120_warped_radii_amended_full.pickle
# -1.440320094979195
# (14, 33)
# matt_preds_graphs_fwhm_single_excel/20200217_17-XYZres124_warped_radii_amended_full.pickle
# -2.049172861498243
# (17, 317)
# matt_preds_graphs_fwhm_single_excel/20200217_9-XYZres71_warped_radii_amended_full.pickle
# 1.3813196489779411
# (20, 207)
# matt_preds_graphs_fwhm_single_excel/20200217_9-XYZres74_warped_radii_amended_full.pickle
# -1.8665853294162942
# (35, 307)
# matt_preds_graphs_fwhm_single_excel/20200227_20-XYZres147_warped_radii_amended_full.pickle
# -1.074550447812995
# (45, 595)
# matt_preds_graphs_fwhm_single_excel/20200227_22-XYZres165_warped_radii_amended_full.pickle
# -1.274644925593842
# (49, 134)
# matt_preds_graphs_fwhm_single_excel/20200227_23-XYZres154_warped_radii_amended_full.pickle
# -1.242988560716265
# (57, 340)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres176_warped_radii_amended_full.pickle
# -1.2735664727303313
# (57, 602)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres176_warped_radii_amended_full.pickle
# -1.2083619347107135
# (58, 66)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.242962208577413
# (58, 247)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.4488507539703464
# (58, 300)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.3794714250047722
# (58, 363)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.2125078263676268
# (58, 401)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.0418518166058297
# (58, 438)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.3404751067595655
# (58, 441)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.1410754559787444
# (58, 503)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.0790370717636457
# (58, 525)
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# -1.399140428590885
# (68, 327)
# matt_preds_graphs_fwhm_single_excel/20200525_32-XYZres199_warped_radii_amended_full.pickle
# 1.4596257815902138
# (81, 34)
# matt_preds_graphs_fwhm_single_excel/20201201_35-XYZres211_warped_radii_amended_full.pickle
# -2.0852069812416714
# (81, 207)
# matt_preds_graphs_fwhm_single_excel/20201201_35-XYZres211_warped_radii_amended_full.pickle
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1297823/4012103487.py in <module>
#      15     img = io.imread(re.sub('_radii_amended_full.pickle','.tif',re.sub('matt_preds_graphs_fwhm_single_excel','matt_raw_warped_single',file)))
#      16     img_0001 = io.imread(re.sub('_radii_amended_full.pickle','.tif',re.sub('matt_preds_graphs_fwhm_single_excel','matt_raw_warped_single',file_0001)))
# ---> 17     img_ch2 = sp.ndimage.zoom(np.swapaxes(img[:,1,:,:],0,2),(1,1,2.645833333),order=0)
#      18     img = sp.ndimage.zoom(np.swapaxes(img[:,0,:,:],0,2),(1,1,2.645833333),order=0)
#      19     img_0001_ch2 = sp.ndimage.zoom(np.swapaxes(img_0001[:,1,:,:],0,2),(1,1,2.645833333),order=0)
#
# /lustre06/project/6023374/rozakmat/monai3.8/lib/python3.8/site-packages/scipy/ndimage/_interpolation.py in zoom(input, zoom, output, order, mode, cval, prefilter, grid_mode)
#     814                         where=zoom_div != 0)
#     815     zoom = numpy.ascontiguousarray(zoom)
# --> 816     _nd_image.zoom_shift(filtered, zoom, None, output, order, mode, cval, npad,
#     817                          grid_mode)
#     818     return output
#
# KeyboardInterrupt:

# %%
#[17,389],[5,199],[37,507],[24,26],[13,9],[0,18]
#[5,368],[37,307],[24,418],[13,456],[13,394],[17,86]
#files_edge = np.array([[17,389],[37,507],[24,26],[13,9],[0,18]])
files_edge = np.array([[21,244],[25,135],[35,81],[45,554]])
files_edge = np.array([[147,144],[155,339],[158,525],[224,213]])
files_edge = np.array([[29, 395],[41, 268],[57, 16],[58, 401],[184, 155]
                       ,[58, 66]])
fig, ax = plt.subplots(len(files_edge),2)
position = ['lower left','lower left', 'lower right','upper left','upper left', 'upper left']
#position = ['lower center','lower center', 'lower center','lower center','lower left', 'upper right']
for i,params in enumerate(files_edge):
    file_0001 = files[params[0]]
    file = re.sub('_0001','',file_0001)
    print(file)
    img = io.imread(re.sub('_radii_amended_full.pickle','.tif',re.sub('matt_preds_graphs_fwhm_single_excel','matt_raw_warped_single',file)))
    img_0001 = io.imread(re.sub('_radii_amended_full.pickle','.tif',re.sub('matt_preds_graphs_fwhm_single_excel','matt_raw_warped_single',file_0001)))
    img_ch2 = sp.ndimage.zoom(np.swapaxes(img[:,1,:,:],0,2),(1,1,2.645833333),order=0)
    img = sp.ndimage.zoom(np.swapaxes(img[:,0,:,:],0,2),(1,1,2.645833333),order=0)
    img_0001_ch2 = sp.ndimage.zoom(np.swapaxes(img_0001[:,1,:,:],0,2),(1,1,2.645833333),order=0)
    img_0001 = sp.ndimage.zoom(np.swapaxes(img_0001[:,0,:,:],0,2),(1,1,2.645833333),order=0)
    graph = nx.read_gpickle(file)
    graph_0001 = nx.read_gpickle(file_0001)
    edges = list(graph.edges)
    edge = edges[params[1]]
    print(edges[params[1]])
    radii = graph.edges[edge]['radii']
    radii_0001 = graph_0001.edges[edge]['radii']
    pts = graph.edges[edge]['pts']
    mx = np.max(pts,axis=0) +5
    mn = np.min(pts,axis=0) - 5
    pt = pts[:,:2]- np.array([mn[0],mn[1]]) - 1
    _img = exposure.equalize_adapthist(np.max(img[mn[0]:mx[0],mn[1]:mx[1],mn[2]:mx[2]],axis=2), clip_limit=0.03)
    _show_img = np.zeros(list(_img.shape) + [3])
    _show_img[:,:,0] = _img
    _show_img[:,:,1] = 0.7*exposure.equalize_adapthist(np.max(img_ch2[mn[0]:mx[0],mn[1]:mx[1],mn[2]:mx[2]],axis=2), clip_limit=0.03)
    ax[i,0].imshow(_show_img)
    ax[i,0].tick_params(left = False, right = False, labelleft = False ,labelbottom = False, bottom = False)
    print(radii_0001-radii)
    ax[i,0].set_ylabel("{:.2f}".format(round((radii_0001-radii)*2, 2)) + str(u' \u03bcm'), rotation=0, fontsize=20, ha='right')
    scalebar = ScaleBar(1,units="um", 
                        length_fraction = 0.5, 
                        location = position[i], 
                        pad=0.1, 
                        color='white', 
                        frameon=False,
                        width_fraction = 0.05) # 1 pixel = 0.2 meter
    scalebar2 = ScaleBar(1,units="um", 
                        length_fraction = 0.5, 
                        location = position[i], 
                        pad=0.1, 
                        color='white', 
                        frameon=False,
                        width_fraction = 0.05) # 1 pixel = 0.2 meter
    ax[i,0].add_artist(scalebar)
    #ax[i,1].add_artist(scalebar2)
    _img_0001 = np.max(img_0001[mn[0]:mx[0],mn[1]:mx[1],mn[2]:mx[2]],axis=2)
    _show_img_0001 = np.zeros(list(_img_0001.shape) + [3])
    _show_img_0001[:,:,0] = exposure.equalize_adapthist(_img_0001, clip_limit=0.03)
    _show_img_0001[:,:,1] = 0.7*exposure.equalize_adapthist(np.max(img_0001_ch2[mn[0]:mx[0],mn[1]:mx[1],mn[2]:mx[2]],axis=2), clip_limit=0.03)
    ax[i,1].imshow(_show_img_0001)
    ax[i,1].tick_params(left = False, right = False , labelleft = False ,labelbottom = False, bottom = False)
fig.set_figheight(16)
fig.set_figwidth(7)
fig.tight_layout()
fig.savefig('seeingIsBeiliving_Matt_large changes.jpeg')
# Out:
# matt_preds_graphs_fwhm_single_excel/20200227_18-XYZres131_warped_radii_amended_full.pickle
# (329, 345)
# 2.494821599663865
# matt_preds_graphs_fwhm_single_excel/20200227_22-XYZres161_warped_radii_amended_full.pickle
# (234, 306)
# 1.8936057282970538
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres176_warped_radii_amended_full.pickle
# (17, 95)
# 5.399161187496345
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# (321, 349)
# -1.0418518166058297
# matt_preds_graphs_fwhm_single_excel/20220129_64-XYZres351_warped_radii_amended_full.pickle
# (137, 159)
# 1.936077871967702
# matt_preds_graphs_fwhm_single_excel/20200411_26-XYZres177_warped_radii_amended_full.pickle
# (57, 75)
# -1.242962208577413

# %%
graph_file = files[224]

# %%
graph_0001 = nx.read_gpickle(graph_file)
graph = nx.read_gpickle(re.sub('_0001','',graph_file))

# %%
b, a = sp.signal.butter(3, 0.05/0.5, btype='low', analog=False, fs=1)
for edge in tqdm(graph.edges):
    graph[edge[0]][edge[1]]['path_weights_filtered'] = graph[edge[0]][edge[1]]['path_weights']#sp.signal.filtfilt(b, a, graph[edge[0]][edge[1]]['path_weights'],padlen=0)
    graph_0001[edge[0]][edge[1]]['path_weights_filtered'] = graph_0001[edge[0]][edge[1]]['path_weights']#sp.signal.filtfilt(b, a, graph_0001[edge[0]][edge[1]]['path_weights'],padlen=0)
# Out:
# 100%|██████████| 419/419 [00:00<00:00, 162108.05it/s]

# %%
matplotlib.rcParams.update({'font.size': 22})
b, a = sp.signal.butter(3, 0.05/0.5, btype='low', analog=False, fs=1)
edges = list(graph.edges)
fig, axs = plt.subplots(1, 1)
edge = edges[213]
y = np.array(graph[edge[0]][edge[1]]['path_weights'])
#y = sp.signal.filtfilt(b, a, y, padlen=0)
y_error = np.array(graph[edge[0]][edge[1]]['path_weights_uncertanty'])#
#y_error = sp.signal.filtfilt(b, a, y_error, padlen=0)
x = np.arange(0,len(y),1)
axs.plot(x,y,label='pre-stimulus', color='#1B0F55')
axs.fill_between(x, y-y_error, y+y_error, alpha=0.5, color='#1B0F55')
y_0001 = np.array(graph_0001[edge[0]][edge[1]]['path_weights'])
#y_0001 = sp.signal.filtfilt(b, a, y_0001, padlen=0)
y_0001_error = np.array(graph_0001[edge[0]][edge[1]]['path_weights_uncertanty'])
#y_0001_error = sp.signal.filtfilt(b, a, y_0001_error, padlen=0)
axs.plot(x,y_0001,label='post-stimulus', color='#455200')
axs.fill_between(x, y_0001-y_0001_error, y_0001+y_0001_error, alpha=0.5, color='#455200')
#ax0 = axs[0].twinx()
#ax0.plot(x,np.array(graph[edge[0]][edge[1]]['path_weights_nrn']),color='red',label='neuron distance')
#axs[0].set_xlabel(u'Distance along vessel centerline (\u03bcm)')
axs.set_ylabel(u'Radius (\u03bcm)')
axs.set_title('Artery')
axs.legend(loc='upper right', fontsize="18")

# %%
matplotlib.rcParams.update({'font.size': 22})
b, a = sp.signal.butter(3, 0.05/0.5, btype='low', analog=False, fs=1)
edges = list(graph.edges)
fig, axs = plt.subplots(1, 1)
y = np.array(graph[edge[0]][edge[1]]['path_weights'])
y = sp.signal.filtfilt(b, a, y, padlen=0)
y_error = np.array(graph[edge[0]][edge[1]]['path_weights_uncertanty'])#
y_error = sp.signal.filtfilt(b, a, y_error, padlen=0)
x = np.arange(0,len(y),1)
axs.plot(x,y,label='pre-stimulus', color='#1B0F55')
axs.fill_between(x, y-y_error, y+y_error, alpha=0.5, color='#1B0F55')
y_0001 = np.array(graph_0001[edge[0]][edge[1]]['path_weights'])
y_0001 = sp.signal.filtfilt(b, a, y_0001, padlen=0)
y_0001_error = np.array(graph_0001[edge[0]][edge[1]]['path_weights_uncertanty'])
y_0001_error = sp.signal.filtfilt(b, a, y_0001_error, padlen=0)
axs.plot(x,y_0001,label='post-stimulus', color='#455200')
axs.fill_between(x, y_0001-y_0001_error, y_0001+y_0001_error, alpha=0.5, color='#455200')
#ax0 = axs[0].twinx()
#ax0.plot(x,np.array(graph[edge[0]][edge[1]]['path_weights_nrn']),color='red',label='neuron distance')
#axs[0].set_xlabel(u'Distance along vessel centerline (\u03bcm)')
axs.set_ylabel(u'Radius (\u03bcm)')
#axs.set_title('Artery')
axs.legend(loc='upper right', fontsize="18")
fig.savefig('vessel_breaks.jpeg')
