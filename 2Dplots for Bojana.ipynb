# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
file_raw = '/home/rozakmat/projects/rrg-bojana/rozakmat/TBI/GT_filtered+raw/114_0001_MAX_Result of C1-Composite.tiff'

# %%
image_raw = io.imread(file_raw)

# %%
image_raw.shape
#image_raw = image_raw[:,0]-image_raw[:,1]
#image_raw[image_raw<0] = 0
#image_raw.shape
# Out:
# (512, 512)

# %%
#image_raw_mip = np.max(image_raw,axis=0)
#image_raw_mip = np.concatenate((image_raw_mip,np.zeros((1,512,512))))
#image_raw_mip = np.swapaxes(image_raw_mip,0,2)
image_raw = image_raw/np.max(image_raw)

# %%
#image_raw_mip.shape

# %%
plt.imshow(image_raw)

# %%
#np.max(image_raw_mip)

# %%
file_mean = '/home/rozakmat/projects/rrg-bojana/rozakmat/TBI_monai_UNET/matt_preds/20200217_14-XYZres114_0001_mean.npy'
img_mean = np.load(file_mean)

# %%
img_mean = img_mean[1]

# %%
img_mean = np.max(img_mean,axis=2)
img_mean = np.swapaxes(img_mean,0,1)

# %%
plt.imshow(img_mean)

# %%
file_std = '/home/rozakmat/projects/rrg-bojana/rozakmat/TBI_monai_UNET/matt_preds/20200217_14-XYZres114_0001_std.npy'
img_std = np.load(file_std)

# %%
img_std = img_std[1]

# %%
img_std = np.max(img_std,axis=2)
img_std = np.swapaxes(img_std,0,1)

# %%
plt.imshow(img_std)

# %%
plt.style.use('dark_background')
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15, 5))
pos1 = ax1.imshow(image_raw,cmap='Greys_r')
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='5%', pad=0.05)
cbar0 = fig.colorbar(pos1, cax=cax, ax=ax1)
cbar0.set_label('Intensity', rotation=270)
ax1.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
ax1.set_title('Maximum Intensity \n Projection of Vasculature')

pos2 = ax2.imshow(img_mean,cmap='Purples_r')
divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='5%', pad=0.05)
cbar1 = fig.colorbar(pos2, cax=cax, ax=ax2)
cbar1.set_label('Mean', rotation=270)
ax2.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False) 
ax2.set_title('Mean Vasculature \n Probability MIP')
#bar1 = plt.colorbar(img_mean)

pos3 = ax3.imshow(img_std,cmap='Greens_r')
divider = make_axes_locatable(ax3)
cax = divider.append_axes('right', size='5%', pad=0.05)
cbar2 = fig.colorbar(pos3,cax=cax,ax=ax3)
cbar2.set_label('STD', rotation=270)
ax3.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
ax3.set_title('STD Vasculature \n Probability MIP')

asp = np.diff(ax2.get_xlim())[0] / np.diff(ax2.get_ylim())[0]
fig.tight_layout()
fig.savefig('segmentation_comparison.png')

# %%
file_raw = '/home/rozakmat/projects/rrg-bojana/rozakmat/TBI/GT_filtered+raw/Result_of_XYZres114_0001.tif'
image_raw = io.imread(file_raw)
image_raw = image_raw/np.max(image_raw)
image_raw.shape
image_raw=np.max(image_raw,axis=2)[::-1]
print(image_raw.shape)
plt.imshow(image_raw)
# Out:
# (252, 507)

# %%
file_mean = '/home/rozakmat/projects/rrg-bojana/rozakmat/TBI_monai_UNET/matt_preds/20200217_14-XYZres114_0001_mean.npy'
img_mean = np.load(file_mean)
img_mean = img_mean[1]
print(img_mean.shape)
img_mean = np.max(img_mean,axis=0)
img_mean = np.swapaxes(img_mean,0,1)[::-1]
plt.imshow(img_mean)
# Out:
# (507, 507, 252)

# %%
file_std = '/home/rozakmat/projects/rrg-bojana/rozakmat/TBI_monai_UNET/matt_preds/20200217_14-XYZres114_0001_std.npy'
img_std = np.load(file_std)
print(img_std.shape)
img_std = img_std[1]
img_std = np.max(img_std,axis=0)
img_std = np.swapaxes(img_std,0,1)[::-1]
plt.imshow(img_std)
# Out:
# (3, 507, 507, 252)

# %%
plt.style.use('dark_background')
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15, 5))
pos1 = ax1.imshow(image_raw,cmap='Greys_r')
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='5%', pad=0.05)
cbar0 = fig.colorbar(pos1, cax=cax, ax=ax1)
cbar0.set_label('Intensity', rotation=270)
ax1.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
ax1.set_title('Maximum Intensity \n Projection of Vasculature')

pos2 = ax2.imshow(img_mean,cmap='Purples_r')
divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='5%', pad=0.05)
cbar1 = fig.colorbar(pos2, cax=cax, ax=ax2)
cbar1.set_label('Mean', rotation=270)
ax2.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False) 
ax2.set_title('Mean Vasculature \n Probability MIP')
#bar1 = plt.colorbar(img_mean)

pos3 = ax3.imshow(img_std,cmap='Greens_r')
divider = make_axes_locatable(ax3)
cax = divider.append_axes('right', size='5%', pad=0.05)
cbar2 = fig.colorbar(pos3,cax=cax,ax=ax3)
cbar2.set_label('STD', rotation=270)
ax3.tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
ax3.set_title('STD Vasculature \n Probability MIP')

asp = np.diff(ax2.get_xlim())[0] / np.diff(ax2.get_ylim())[0]
fig.tight_layout()
fig.savefig('segmentation_comparison_otherview.png')
